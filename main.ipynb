# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mtcnn
# Out:
# ...
#   Using cached keras-3.8.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# ...
#   Using cached h5py-3.12.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (2.5 kB)
# ...
#   Using cached optree-0.14.0-cp39-cp39-macosx_10_9_universal2.whl.metadata (47 kB)
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 7.0 MB/s eta 0:00:00a 0:00:01
# Using cached keras-3.8.0-py3-none-any.whl (1.3 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached h5py-3.12.1-cp39-cp39-macosx_10_9_x86_64.whl (3.4 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 667.6/667.6 kB 6.3 MB/s eta 0:00:00
# Using cached namex-0.0.8-py3-none-any.whl (5.8 kB)
# ...

# %%
# !pip install tensorflow-macos
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.4/228.4 MB 6.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 6.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 6.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 7.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 MB 7.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 6.7 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: keras
# ...

# %%
import cv2 as cv
import os
import numpy as np

# %%
import tensorflow as tf

# %%
# !pip uninstall jax jaxlib
# Out:
# WARNING: Skipping jax as it is not installed.
# WARNING: Skipping jaxlib as it is not installed.

# %%
import matplotlib.pyplot as plt
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
img = cv.imread("/Users/salam9/Downloads/face_recognition/dataset/shoaib_alam/DSC08383.JPG")
# opencv BGR channel format and plt reads images as RGB channel format

# %%
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img) # RGB

# %%
from mtcnn.mtcnn import MTCNN

detector = MTCNN()
results = detector.detect_faces(img)
# Out:
# ...
# 1/1 [==============================] - 0s 124ms/step

# %%
results
# Out:
# [{'box': [2546, 1175, 344, 429],
#   'confidence': 1.0,
#   'keypoints': {'left_eye': (2644, 1330),
#    'right_eye': (2803, 1322),
#    'nose': (2731, 1423),
#    'mouth_left': (2655, 1489),
#    'mouth_right': (2814, 1484)}}]

# %%
x,y,w,h = results[0]['box']

# %%
img = cv.rectangle(img, (x,y), (x+w, y+h), (0,0,255), 30)
plt.imshow(img)

# %%
my_face = img[y:y+h, x:x+w]
#Facenet takes as input 160x160 
my_face = cv.resize(my_face, (160,160))
plt.imshow(my_face)

# %%
my_face
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        ...,
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
# ...

# %% [markdown]
# # Automate the preprocessing

# %%
class FACELOADING:
    def __init__(self, directory):
        self.directory = directory
        self.target_size = (160,160)
        self.X = []
        self.Y = []
        self.detector = MTCNN()
    

    def extract_face(self, filename):
        img = cv.imread(filename)
        img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
        x,y,w,h = self.detector.detect_faces(img)[0]['box']
        x,y = abs(x), abs(y)
        face = img[y:y+h, x:x+w]
        face_arr = cv.resize(face, self.target_size)
        return face_arr
    

    def load_faces(self, dir):
        FACES = []
        for im_name in os.listdir(dir):
            try:
                path = dir + im_name
                single_face = self.extract_face(path)
                FACES.append(single_face)
            except Exception as e:
                pass
        return FACES

    def load_classes(self):
        for sub_dir in os.listdir(self.directory):
            path = self.directory +'/'+ sub_dir+'/'
            FACES = self.load_faces(path)
            labels = [sub_dir for _ in range(len(FACES))]
            print(f"Loaded successfully: {len(labels)}")
            self.X.extend(FACES)
            self.Y.extend(labels)
        
        return np.asarray(self.X), np.asarray(self.Y)


    def plot_images(self):
        plt.figure(figsize=(18,16))
        for num,image in enumerate(self.X):
            ncols = 3
            nrows = len(self.Y)//ncols + 1
            plt.subplot(nrows,ncols,num+1)
            plt.imshow(image)
            plt.axis('off')

# %%
faceloading = FACELOADING("/Users/salam9/Downloads/face_recognition/dataset")
X, Y = faceloading.load_classes()
# Out:
# ...
# 1/1 [==============================] - 0s 59ms/step
# libpng warning: iCCP: known incorrect sRGB profile
# ...
# 1/1 [==============================] - 0s 26ms/step
# Loaded successfully: 7
# ...
# 1/1 [==============================] - 0s 27ms/step
# Loaded successfully: 10
# ...
# 1/1 [==============================] - 0s 24ms/step
# Loaded successfully: 10
# ...
# 1/1 [==============================] - 0s 26ms/step
# Loaded successfully: 10
# ...
# 1/1 [==============================] - 0s 24ms/step
# Loaded successfully: 10

# %%
plt.figure(figsize=(16,12))
for num,image in enumerate(X):
    ncols = 3
    nrows = len(Y)//ncols + 1
    plt.subplot(nrows,ncols,num+1)
    plt.imshow(image)
    plt.axis('off')

# %% [markdown]
# # FaceNet part

# %%
# !pip install keras-facenet
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for keras-facenet: filename=keras_facenet-0.3.2-py3-none-any.whl size=10386 sha256=881d1d8f33e445fa7f31ffd3392203ca2218a92fb9eef9ece64387de31f6313e
#   Stored in directory: /Users/salam9/Library/Caches/pip/wheels/73/5d/41/90b5d28ca667cfc4748ae859fa4f0b85b936d73207a073ded5
# Successfully built keras-facenet
# ...

# %%
from keras_facenet import FaceNet
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

embedder = FaceNet()

def get_embedding(face_img):
    face_img = face_img.astype('float32') # 3D(160x160x3)
    face_img = np.expand_dims(face_img, axis=0) 
    # 4D (Nonex160x160x3)
    yhat= embedder.embeddings(face_img)
    return yhat[0] # 512D image (1x1x512)

# %%
EMBEDDED_X = []

for img in X:
    EMBEDDED_X.append(get_embedding(img))

EMBEDDED_X = np.asarray(EMBEDDED_X)
# Out:
# ...
# 1/1 [==============================] - 0s 55ms/step

# %%
np.savez_compressed('/Users/salam9/Downloads/face_recognition/faces_embeddings_done_4classes.npz', EMBEDDED_X, Y)

# %% [markdown]
# # SVM model

# %%
# !pip install scikit-learn
# Out:
# ...
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 7.1 MB/s eta 0:00:00a 0:00:01
# ...
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(Y)
Y = encoder.transform(Y)

# %%
plt.plot(EMBEDDED_X[0]) 
plt.ylabel(Y[0])
# Out:
# Text(0, 0.5, '3')

# %%
break
# Out:
#   File "<ipython-input-21-6aaf1f276005>", line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
Y

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(EMBEDDED_X, Y, shuffle=True, random_state=17)

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear', probability=True)
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
ypreds_train = model.predict(X_train)
ypreds_test = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(Y_train, ypreds_train)
# Out:
# 1.0

# %%
accuracy_score(Y_test,ypreds_test)
# Out:
# 1.0

# %%
t_im = cv.imread("/Users/salam9/Downloads/face_recognition/shoaib_test.jpg")
t_im = cv.cvtColor(t_im, cv.COLOR_BGR2RGB)
x,y,w,h = detector.detect_faces(t_im)[0]['box']
# Out:
# ...
# 1/1 [==============================] - 0s 29ms/step

# %%
t_im = t_im[y:y+h, x:x+w]
t_im = cv.resize(t_im, (160,160))
test_im = get_embedding(t_im)
# Out:
# 1/1 [==============================] - 0s 109ms/step

# %%
test_im = [test_im]
ypreds = model.predict(test_im)

# %%
ypreds
# Out:
# array([3])

# %%
encoder.inverse_transform(ypreds)
# Out:
# array(['shoaib_alam'], dtype='<U18')

# %%
import pickle
#save the model
with open('/Users/salam9/Downloads/face_recognition/svm_model_160x160.pkl','wb') as f:
    pickle.dump(model,f)

# %%
# face recognition part II
#IMPORT
import cv2 as cv
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
import pickle
from keras_facenet import FaceNet
#INITIALIZE
facenet = FaceNet()
faces_embeddings = np.load("/Users/salam9/Downloads/face_recognition/faces_embeddings_done_4classes.npz")
Y = faces_embeddings['arr_1']
encoder = LabelEncoder()
encoder.fit(Y)
haarcascade = cv.CascadeClassifier("/Users/salam9/Downloads/face_recognition/haarcascade_frontalface_default.xml")
model = pickle.load(open("/Users/salam9/Downloads/face_recognition/svm_model_160x160.pkl", 'rb'))

cap = cv.VideoCapture(1)
# WHILE LOOP

while cap.isOpened():
    _, frame = cap.read()
    rgb_img = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
    gray_img = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    faces = haarcascade.detectMultiScale(gray_img, 1.3, 5)
    for x,y,w,h in faces:
        img = rgb_img[y:y+h, x:x+w]
        img = cv.resize(img, (160,160)) # 1x160x160x3
        img = np.expand_dims(img,axis=0)
        ypred = facenet.embeddings(img)
        face_name = model.predict(ypred)
        final_name = encoder.inverse_transform(face_name)[0]
        cv.rectangle(frame, (x,y), (x+w,y+h), (255,0,255), 10)
        cv.putText(frame, str(final_name), (x,y-10), cv.FONT_HERSHEY_SIMPLEX,
                   1, (0,0,255), 3, cv.LINE_AA)

    cv.imshow("Face Recognition:", frame)
    if cv.waitKey(1) & ord('q') ==27:
        break

cap.release()
cv.destroyAllWindows
# Out:
# OpenCV: out device of bound (0-0): 1
# OpenCV: camera failed to properly initialize!
# <function destroyAllWindows>
